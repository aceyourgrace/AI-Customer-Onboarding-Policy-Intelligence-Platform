# %%
import pandas as pd

df1 = pd.read_csv("../data/raw/bank_leads_v4.csv", sep="\t")

df1.head()
# Out:
#    LeadID      LeadSource  Age  Gender EmploymentStatus        Income  \
# 0  L00001        Referral   39  Female    Self-employed  60679.910156
# 1  L00002     Partnership   19    Male        Part-time  48959.320312
# 2  L00003    Social Media   21    Male          Unknown  28953.990234
# 3  L00004  Branch Walk-in   62  Female        Part-time  75863.070312
# 4  L00005       Online Ad   30  Female    Self-employed  48526.550781
#
#   MaritalStatus          Province InitialProductInterest  \
# 0      Divorced  British Columbia            Credit Card
# 1        Single            Quebec            Credit Card
# 2       Married  British Columbia             Investment
# 3        Single            Quebec            Credit Card
# 4       Married           Ontario       Chequing Account
#
#    WebsiteVisits_PreConversion  ...  FirstProductTaken  \
# 0                            2  ...                NaN
# 1                            2  ...                NaN
# ...

# %%
df1.shape
# Out:
# (20000, 31)

# %%
df1.columns.tolist()
# Out:
# ['LeadID',
#  'LeadSource',
#  'Age',
#  'Gender',
#  'EmploymentStatus',
#  'Income',
#  'MaritalStatus',
#  'Province',
#  'InitialProductInterest',
#  'WebsiteVisits_PreConversion',
#  'TimeOnWebsite_Minutes',
#  'EmailOpenedCount',
#  'DaysSinceInquiry',
#  'CallCenterInquiries',
#  'BranchVisits',
#  'ReferrerCustomer',
#  'HasExistingProducts',
#  'FirstContactChannel',
#  'ConversionProbability',
#  'ConversionClass',
#  'ConvertedFlag',
#  'FirstProductTaken',
#  'FirstTransactionAmount',
#  'MonthlyRevenue',
#  'TenureMonths',
#  'CLTV',
#  'EngagementScore',
#  'AgeGroup',
#  'HighValueLead',
#  'AgeScore',
#  'LeadPriorityScore']

# %%
df1['ConversionClass'].value_counts()
# Out:
# ConversionClass
# High      15274
# Medium     4414
# Low         312
# Name: count, dtype: int64

# %%
df1['ConversionClass'].value_counts(normalize=True)
# Out:
# ConversionClass
# High      0.7637
# Medium    0.2207
# Low       0.0156
# Name: proportion, dtype: float64
